# %%
# %load_ext autoreload
# %autoreload 2
from app.div7a import *
#div7a2_from_json({"loan_year": 2020, "full_term": 7, "opening_balance": 100000.0, "opening_balance_year": 2020, "repayments": [{"date": "2023-11-25", "amount": 0.0}], "lodgement_date": "2021-06-30"})
div7a2_from_json({"loan_year": 2020, "full_term": 7, "opening_balance": 100000.0, "opening_balance_year": 2020, "repayments": [{"date": "2021-06-30", "amount": 17000.0}, {"date": "2022-06-30", "amount": 10000.0}, {"date": "2023-06-30", "amount": 10000.0}, {"date": "2024-06-30", "amount": 10000.0}], "lodgement_date": "2021-06-30"})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# evaluate_myr_checks
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uuid</th>
#       <th>year</th>
#       <th>remain</th>
#       <th>fiscal</th>
#       <th>date</th>
#       <th>type</th>
#       <th>final_balance</th>
#       <th>term</th>
#       <th>note</th>
#       <th>rate</th>
#       <th>amount</th>
#       <th>days</th>
#       <th>sorting</th>
#       <th>interest_accrued</th>
#       <th>total_repaid</th>
#       <th>total_repaid_for_myr_calc</th>
#       <th>counts_towards_initial_balance</th>
#       <th>myr_required</th>
#       <th>shortfall</th>
#       <th>excess</th>
#       <th>principal</th>
#       <th>periods</th>
#       <th>myr_check_previous_income_year_final_balance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>341</td>
#       <td>0</td>
#       <td></td>
#       <td>2020</td>
# ...
