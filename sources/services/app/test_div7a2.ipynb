# %%
# %load_ext autoreload
# %autoreload 2
from app.div7a import *
#div7a2_from_json({"loan_year": 2020, "full_term": 7, "opening_balance": 100000.0, "opening_balance_year": 2020, "repayments": [{"date": "2023-11-25", "amount": 0.0}], "lodgement_date": "2021-06-30"})
div7a2_from_json({"loan_year": 2020, "full_term": 7, "opening_balance": 100000.0, "opening_balance_year": 2020, "repayments": [{"date": "2021-06-30", "amount": 10000.0}, {"date": "2022-06-30", "amount": 10000.0}, {"date": "2023-06-30", "amount": 10000.0}, {"date": "2024-06-30", "amount": 10000.0}, {"date": "2025-06-30", "amount": 10000.0}, {"date": "2026-06-30", "amount": 10000.0}, {"date": "2027-06-30", "amount": 10000.0}], "lodgement_date": "2021-06-30"})
# Out:
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 429, in __call__
#     abs_path_real_path_and_base = NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# NameError: name 'NORM_PATHS_AND_BASE_CONTAINER' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 431, in __call__
#     abs_path_real_path_and_base = get_abs_path_real_path_and_base_from_frame(frame)
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 429, in __call__
#     abs_path_real_path_and_base = NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# NameError: name 'NORM_PATHS_AND_BASE_CONTAINER' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 431, in __call__
#     abs_path_real_path_and_base = get_abs_path_real_path_and_base_from_frame(frame)
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 429, in __call__
#     abs_path_real_path_and_base = NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 431, in __call__
#     abs_path_real_path_and_base = get_abs_path_real_path_and_base_from_frame(frame)
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 429, in __call__
#     abs_path_real_path_and_base = NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 431, in __call__
#     abs_path_real_path_and_base = get_abs_path_real_path_and_base_from_frame(frame)
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 230, in _NormPaths
#     return NORM_PATHS_CONTAINER[filename]
# KeyError: '/usr/lib/python3.10/posixpath.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 429, in __call__
#     abs_path_real_path_and_base = NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 431, in __call__
#     abs_path_real_path_and_base = get_abs_path_real_path_and_base_from_frame(frame)
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 230, in _NormPaths
#     return NORM_PATHS_CONTAINER[filename]
# KeyError: '/usr/lib/python3.10/posixpath.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 429, in __call__
#     abs_path_real_path_and_base = NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 431, in __call__
#     abs_path_real_path_and_base = get_abs_path_real_path_and_base_from_frame(frame)
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 230, in _NormPaths
#     return NORM_PATHS_CONTAINER[filename]
# KeyError: '/usr/lib/python3.10/posixpath.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 429, in __call__
#     abs_path_real_path_and_base = NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 431, in __call__
#     abs_path_real_path_and_base = get_abs_path_real_path_and_base_from_frame(frame)
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 230, in _NormPaths
#     return NORM_PATHS_CONTAINER[filename]
# KeyError: '/usr/lib/python3.10/posixpath.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 429, in __call__
#     abs_path_real_path_and_base = NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 431, in __call__
#     abs_path_real_path_and_base = get_abs_path_real_path_and_base_from_frame(frame)
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 429, in __call__
#     abs_path_real_path_and_base = NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 431, in __call__
#     abs_path_real_path_and_base = get_abs_path_real_path_and_base_from_frame(frame)
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 429, in __call__
#     abs_path_real_path_and_base = NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: '/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py", line 431, in __call__
#     abs_path_real_path_and_base = get_abs_path_real_path_and_base_from_frame(frame)
#   File "/snap/pycharm-professional/359/plugins/python/helpers/pydev/pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# [autoreload of _pydevd_bundle.pydevd_frame failed: Traceback (most recent call last):
#   File "/home/koom/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/venv/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/koom/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/venv/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 612, in _exec
#   File "<frozen importlib._bootstrap>", line 556, in _init_module_attrs
#   File "<frozen importlib._bootstrap>", line 397, in cached
#   File "<frozen importlib._bootstrap_external>", line 513, in _get_cached
#   File "<frozen importlib._bootstrap_external>", line 406, in cache_from_source
#   File "<frozen importlib._bootstrap_external>", line 134, in _path_split
#   File "<frozen importlib._bootstrap_external>", line 134, in <genexpr>
# NameError: name 'NO_FTRACE' is not defined
# ]
# [autoreload of pydevd failed: Traceback (most recent call last):
#   File "/home/koom/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/venv/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/koom/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/venv/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/koom/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/venv/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/koom/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/venv/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/home/koom/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/venv/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'ThreadsSuspendedSingleNotification' object layout differs from 'ThreadsSuspendedSingleNotification'
# ]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# MyException                               Traceback (most recent call last)
# Cell In[2], line 5
#       3 from app.div7a import *
#       4 #div7a2_from_json({"loan_year": 2020, "full_term": 7, "opening_balance": 100000.0, "opening_balance_year": 2020, "repayments": [{"date": "2023-11-25", "amount": 0.0}], "lodgement_date": "2021-06-30"})
# ----> 5 div7a2_from_json({"loan_year": 2020, "full_term": 7, "opening_balance": 100000.0, "opening_balance_year": 2020, "repayments": [{"date": "2021-06-30", "amount": 10000.0}, {"date": "2022-06-30", "amount": 10000.0}, {"date": "2023-06-30", "amount": 10000.0}, {"date": "2024-06-30", "amount": 10000.0}, {"date": "2025-06-30", "amount": 10000.0}, {"date": "2026-06-30", "amount": 10000.0}, {"date": "2027-06-30", "amount": 10000.0}], "lodgement_date": "2021-06-30"})
#
# File ~/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/app/div7a.py:324, in div7a2_from_json(j, tmp_dir_path)
#     321 	json.dump(j, ooo, indent=True)
#     322 	print(f'</code></pre></big>', file=ooo)
# --> 324 r = div7a2_from_json2(ooo, j)
#     326 if ooo:
#     327 	print(f'<h3>response</h3>', file=ooo)
#
# File ~/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/app/div7a.py:369, in div7a2_from_json2(ooo, j)
#     365 	log.warn(records)
#     367 # computation
# --> 369 records = div7a(ooo, records)
#     371 # answer
#     373 overview = []
#
# File ~/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/app/div7a.py:151, in div7a(ooo, records)
#     147 def div7a(ooo, records):
#     148
#     149 	# we begin with loan_start, optional opening_balance, possible lodgement day, and then repayments.
#     150 	tables = [list(records)]
# --> 151 	step(ooo, tables, input)
#     152 	# insert opening_balance record if it's not there
#     153 	step(ooo, tables, ensure_opening_balance_exists)
#
# File ~/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/app/div7a.py:175, in step(ooo, tables, f, final)
#     173 def step(ooo, tables, f, final=False):
#     174 	t1 = tables[-1]
# --> 175 	check_invariants(t1)
#     176 	t2 = [r.copy() for r in t1]
#     177 	f(t2)
#
# File ~/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/app/div7a_checks.py:42, in check_invariants(records)
#      38 		raise MyException('Opening balance is not positive')
#      40 # 	loan_start is before calculation_start:
# ---> 42 if records.index(one([r for r in records if r.__class__ == calculation_start])) <= records.index(one([r for r in records if r.__class__ == loan_start])):
#      43 	raise MyException('loan_start is before calculation_start')
#      45 if records.index(one([r for r in records if r.__class__ == calculation_start])) >= records.index(one([r for r in records if r.__class__ == loan_term_end])):
#
# File ~/repos/koo5/accounts-assessor/0/accounts-assessor/sources/services/app/div7a_impl.py:272, in one(xs)
#     270 def one(xs):
#     271 	if len(xs) != 1:
# --> 272 		raise MyException(f'Expected one element, but got {len(xs)}')
#     273 	return xs[0]
#
# MyException: Expected one element, but got 0
